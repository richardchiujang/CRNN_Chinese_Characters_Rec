# %% [markdown]
# # 利用函數 trdg_gen_sample 與迴圈
# ###  輸入不同樣本參數產生多個資料夾的多種樣本
# ###  trdg_gen_sample(output_dir, cmd_str)
# ###  cmd_str_tuple = ((資料夾名稱, 樣本參數), (資料夾名稱, 樣本參數), ...)
# ###  for output_dir, cmd_str in cmd_str_tuple:

# %%
# import os
# import time

# os.getcwd()
# os.chdir('C:/develop/TextRecognitionDataGenerator/trdg/')
# os.getcwd()

# %%
# def trdg_gen_sample(output_dir, cmd_str):
#     output_dir = ' --output_dir ' + output_dir
#     cmd_str = cmd_str
#     # print('PROCESS {}{}'.format(cmd_str, output_dir))
#     stime = time.time()
#     os.system('python run.py {}{}'.format(cmd_str, output_dir))
#     runtime = time.time() - stime
#     time.sleep(1)
#     return print('job finished {:5.2f} {}{}'.format(runtime, cmd_str, output_dir))

# %%
cmd_str_tuple = (
    # 輸出格式 -na 2; 輸出字數 -w; 執行序數量 -t; 產生樣本數 -c; 樣本置中 -al 1 
     
    # 英數字
    # 傾斜 -k -rk
    # 只有數字; 字間間格(像素) -cs 0 ;字間間格(空白(數)) -sw 1; 緊密的填滿(字較大傾向填滿上下空間) -fi; 背景全白 -b 1; 隨機模糊 -bl 1 -rbl 
    # 產生樣本字體顏色區間 -tc "#000000,#888888"; 背景為輸入圖片 -b 3 (彩色背景)    
    # 產生樣本字體顏色區間 -tc "#EEEEEE,#FFFFFF"; 背景為輸入圖片 -b 3 (反白樣本)
    # 垂直 -or 1; 水平 -ro 0 (預設)
    # [DISTORSION] -d 0 -do 1 0: None (Default), 1: Sine wave, 2: Cosine wave, 3: Random 
    # [DISTORSION_ORIENTATION] -do 0: Vertical (Up and down), 1: Horizontal(Left and Right)

    (     'wn_cs0sw1_num0_fi_k','-t 24 -c 100000 -w 3 -cs 0 -sw 1 -na 2 -al 1 -fi -b 1 -bl 1 -rbl -k 1 -rk'),
    (      'wn_cs0sw1_num_fi_k','-t 24 -c 100000 -w 3 -rs -num -cs 0 -sw 1 -na 2 -al 1 -fi -b 0 -bl 1 -rbl -k 1 -rk'),
    (       'wn_cs0sw1_num0_fi','-t 24 -c 100000 -w 3 -cs 0 -sw 1 -na 2 -al 1 -fi -b 1 -bl 1 -rbl'),
    (        'wn_cs0sw1_num_fi','-t 24 -c 100000 -w 3 -rs -num -cs 0 -sw 1 -na 2 -al 1 -fi -b 0 -bl 1 -rbl'),    
    (    'wn_cs0sw1_num0_fi_tc','-t 24 -c 100000 -w 3 -cs 0 -sw 1 -na 2 -al 1 -fi -b 3 -bl 1 -rbl -tc "#000000,#888888"'),
    (     'wn_cs0sw1_num_fi_tc','-t 24 -c 100000 -w 3 -rs -num -cs 0 -sw 1 -na 2 -al 1 -fi -b 3 -bl 1 -rbl -tc "#000000,#888888"'),
    (  'wn_cs0sw1_num0_fi_tcFF','-t 24 -c 100000 -w 3 -cs 0 -sw 1 -na 2 -al 1 -fi -b 3 -bl 1 -rbl -tc "#EEEEEE,#FFFFFF" -b 3'),
    (   'wn_cs0sw1_num_fi_tcFF','-t 24 -c 100000 -w 3 -rs -num -cs 0 -sw 1 -na 2 -al 1 -fi -b 3 -bl 1 -rbl -tc "#EEEEEE,#FFFFFF" -b 3'),
    (      'w20_cs0sw0_nofi_or','-t 24 -c 100000 -l bo -w 20 -cs 0 -sw 0 -na 2 -or 1 -al 1 -b 1'),
    (        'w20_cs0sw0_fi_or','-t 24 -c 100000 -l bo -w 20 -cs 0 -sw 0 -na 2 -or 1 -al 1 -b 1 -fi'),
    (      'w14_cs0sw1_nofi_or','-t 24 -c 100000 -l bo -w 14 -cs 0 -sw 1 -na 2 -or 1 -al 1 -b 1'),
    (        'w14_cs0sw1_fi_or','-t 24 -c 100000 -l bo -w 14 -cs 0 -sw 1 -na 2 -or 1 -al 1 -b 1 -fi'),    
    (   'w20_cs0sw0_nofi_or_tc','-t 24 -c 100000 -l bo -w 20 -cs 0 -sw 0 -na 2 -or 1 -al 1 -tc "#000000,#888888" -b 3'),
    (     'w20_cs0sw0_fi_or_tc','-t 24 -c 100000 -l bo -w 20 -cs 0 -sw 0 -na 2 -or 1 -al 1 -tc "#000000,#888888" -b 3 -fi'),
    ( 'w14_cs0sw1_nofi_or_tcFF','-t 24 -c 100000 -l bo -w 14 -cs 0 -sw 1 -na 2 -or 1 -al 1 -tc "#EEEEEE,#FFFFFF" -b 3'),
    (   'w14_cs0sw1_fi_or_tcFF','-t 24 -c 100000 -l bo -w 14 -cs 0 -sw 1 -na 2 -or 1 -al 1 -tc "#EEEEEE,#FFFFFF" -b 3 -fi'), 
    (    'w20_cs0sw0_nofi_or_d','-t 24 -c 100000 -l bo -w 20 -cs 0 -sw 0 -na 2 -or 1 -al 1 -d 0 -do 1 -b 0'),
    (      'w20_cs0sw0_fi_or_d','-t 24 -c 100000 -l bo -w 20 -cs 0 -sw 0 -na 2 -or 1 -al 1 -d 0 -do 1 -b 0 -fi'),
    (    'w14_cs0sw1_nofi_or_d','-t 24 -c 100000 -l bo -w 14 -cs 0 -sw 1 -na 2 -or 1 -al 1 -d 0 -do 1 -b 0'),
    (      'w14_cs0sw1_fi_or_d','-t 24 -c 100000 -l bo -w 14 -cs 0 -sw 1 -na 2 -or 1 -al 1 -d 0 -do 1 -b 0 -fi'),   
    (    'w20_cs0sw0_nofi_or_k','-t 24 -c 100000 -l bo -w 20 -cs 0 -sw 0 -na 2 -or 1 -al 1 -k 1 -rk -b 0'),
    (      'w20_cs0sw0_fi_or_k','-t 24 -c 100000 -l bo -w 20 -cs 0 -sw 0 -na 2 -or 1 -al 1 -k 1 -rk -b 0 -fi'),
    (    'w14_cs0sw1_nofi_or_k','-t 24 -c 100000 -l bo -w 14 -cs 0 -sw 1 -na 2 -or 1 -al 1 -k 1 -rk -b 0'),
    (      'w14_cs0sw1_fi_or_k','-t 24 -c 100000 -l bo -w 14 -cs 0 -sw 1 -na 2 -or 1 -al 1 -k 1 -rk -b 0 -fi'),  
    (         'w36_cs0sw0_nofi','-t 24 -c 200000 -l bo -w 36 -cs 0 -sw 0 -na 2 -wd 888 -al 1 -b 1'),
    (           'w36_cs0sw0_fi','-t 24 -c 200000 -l bo -w 36 -cs 0 -sw 0 -na 2 -wd 888 -al 1 -b 1 -fi'),
    (         'w24_cs0sw1_nofi','-t 24 -c 200000 -l bo -w 24 -cs 0 -sw 1 -na 2 -wd 888 -al 1 -b 1'),
    (           'w24_cs0sw1_fi','-t 24 -c 200000 -l bo -w 24 -cs 0 -sw 1 -na 2 -wd 888 -al 1 -b 1 -fi'),
    (     'w36_cs0sw0_bl_tc_b3','-t 24 -c 200000 -l bo -w 36 -cs 0 -sw 0 -na 2 -wd 888 -al 1 -bl 1 -rbl -tc "#000000,#888888" -b 3'),
    (  'w36_cs0sw0_bl_tc_b3_fi','-t 24 -c 200000 -l bo -w 36 -cs 0 -sw 0 -na 2 -wd 888 -al 1 -bl 1 -rbl -tc "#000000,#888888" -b 3 -fi'),
    (     'w24_cs0sw1_bl_tc_b3','-t 24 -c 200000 -l bo -w 24 -cs 0 -sw 1 -na 2 -wd 888 -al 1 -bl 1 -rbl -tc "#000000,#888888" -b 3'),
    (  'w24_cs0sw1_bl_tc_b3_fi','-t 24 -c 200000 -l bo -w 24 -cs 0 -sw 1 -na 2 -wd 888 -al 1 -bl 1 -rbl -tc "#000000,#888888" -b 3 -fi'),
    (   'w36_cs0sw0_bl_tcFF_b3','-t 24 -c 200000 -l bo -w 36 -cs 0 -sw 0 -na 2 -wd 888 -al 1 -bl 1 -rbl -tc "#EEEEEE,#FFFFFF" -b 3'),
    ('w36_cs0sw0_bl_tcFF_b3_fi','-t 24 -c 200000 -l bo -w 36 -cs 0 -sw 0 -na 2 -wd 888 -al 1 -bl 1 -rbl -tc "#EEEEEE,#FFFFFF" -b 3 -fi'),
    (    'w36_cs0sw0_nofi_b0_k','-t 24 -c 200000 -l bo -w 36 -cs 0 -sw 0 -na 2 -wd 888 -al 1 -b 0 -k 1 -rk'),
    (      'w36_cs0sw0_fi_b0_k','-t 24 -c 200000 -l bo -w 36 -cs 0 -sw 0 -na 2 -wd 888 -al 1 -b 0 -fi -k 1 -rk'),
    (    'w24_cs0sw1_nofi_b0_k','-t 24 -c 200000 -l bo -w 24 -cs 0 -sw 1 -na 2 -wd 888 -al 1 -b 0 -k 1 -rk'),
    (      'w24_cs0sw1_fi_b0_k','-t 24 -c 200000 -l bo -w 24 -cs 0 -sw 1 -na 2 -wd 888 -al 1 -b 0 -fi -k 1 -rk'),
    (    'w36_cs0sw0_nofi_b0_d','-t 24 -c 200000 -l bo -w 36 -cs 0 -sw 0 -na 2 -wd 888 -al 1 -b 0 -d 1 -do 0'),
    (      'w36_cs0sw0_fi_b0_d','-t 24 -c 200000 -l bo -w 36 -cs 0 -sw 0 -na 2 -wd 888 -al 1 -b 0 -d 1 -do 0 -fi '),
    (    'w24_cs0sw1_nofi_b0_d','-t 24 -c 200000 -l bo -w 24 -cs 0 -sw 1 -na 2 -wd 888 -al 1 -b 0 -d 1 -do 0'),
    (      'w24_cs0sw1_fi_b0_d','-t 24 -c 200000 -l bo -w 24 -cs 0 -sw 1 -na 2 -wd 888 -al 1 -b 0 -d 1 -do 0 -fi '),
    )

# %%
# i = 0
# for out, cmd_str in cmd_str_tuple:
#     # output_dir = ' --output_dir ' + out
#     # print('python run.py {}{}'.format(cmd_str, output_dir))
#     trdg_gen_sample(out, cmd_str)
#     i += 1
# print('total {} jobs'.format(i))

# %%
# import os
# from PIL import Image
# import tqdm
# # set parameters
# folder_and_prfix_name = 'test_100000'
# source_path = 'out'
# target_root = '../datasets'
# img_size = 888
# if os.path.exists(target_root + '/' + folder_and_prfix_name):
#     print('folder already exist')
# else:
#     os.mkdir(target_root + '/' + folder_and_prfix_name)
#     print('folder {} created'.format(folder_and_prfix_name))
# target_path = target_root + '/' + folder_and_prfix_name

# with open('out/labels.txt', 'r', encoding='utf-8') as labels:
#     lines = labels.readlines()
#     new_lines = []
#     for line in tqdm.tqdm(lines):
#         # print(line)
#         jpg_name = line.split(' ')[0]
#         source_jpg_name = source_path + '/' + jpg_name
#         target_jpg_name = target_path + '/' + folder_and_prfix_name + '_' + jpg_name
#         # print(source_jpg_name, target_jpg_name)
#         # check img size length limit 280
#         # 新增排除沒有生圖的問題
#         try:
#             with Image.open(source_jpg_name) as img:
#             # 获取图像尺寸大小（width, height）
#                 w, h = img.size
#                 if w > h and w > img_size:
#                     img.close()
#                     pass # 超過長度限制就跳過
#                 elif w < h and h > img_size:
#                     img.close()
#                     pass # 超過長度限制
#                 else:
#                     img.close() # 關掉才搬得動   
#                     # move jpg to target path and rename
#                     os.rename(source_jpg_name, target_jpg_name)
#                     # change label.txt
#                     new_line = folder_and_prfix_name + '_' + line
#                     # print(new_line)
#                     new_lines.append(new_line)
#         except:
#             pass
# # write new labels.txt
# with open(target_path + '/' + 'labels.txt', 'w', encoding='utf-8') as file:
#     print(len(new_lines))
#     for item in tqdm.tqdm(new_lines):
#         file.write(item)

# %%
# 比對 label.txt 是否都存在於 alphabet.txt

# 讀取 alphabet.txt
with open(r'..\..\lib\config\alphabets.py', 'r', encoding='utf-8') as f:
    alines = f.readlines()

# print('lines:', len(alines[0][14:-4]))

alphabet = alines[0]
print('alphabet:', len(alphabet))

# 讀取 label.txt
with open(r'C:\develop\CRNN_Chinese_Characters_Rec_data\datasets\train\labels.txt', 'r', encoding='utf-8') as f:
    lines = f.readlines()

# print('lines:', len(lines))

# 比對 label.txt 是否都存在於 alphabet.txt
for line in lines:
    # print('line:', line)
    check = line.replace("\r", "").replace("\n", "").split('.jpg ')[1]
    # print('check:{}.'.format(check))
    for char in check:
        # print('char:', char)
        if char not in alphabet:
            print('char:', char)
            print('line:', line)
            print('label.txt char not in alphabet.txt')
            break
# Out:
# alphabet: 7941
